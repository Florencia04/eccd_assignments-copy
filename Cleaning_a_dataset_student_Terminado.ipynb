# %% [markdown]
# <a href="https://colab.research.google.com/github/Florencia04/eccd_assignments-copy/blob/main/Cleaning_a_dataset_student_Terminado.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Objective
#
# The objective of this notebook is get hands-on experience on cleaning a "dirty" dataset.
# Often, datasets are created from "free-text" fields. In free-text fields, data validation is not enforced and as a result, many conventions co-exist within the same column of data.
# Dirty data can also ocurr when collection information from different sources. If these sources use different conventions to represent such data, additional efforts are required to homogenize it at a later stage.

# %% [markdown]
# ## Setup

# %%
# !pip install -q eccd_datasets pygradus

# %%
STUDENT_NAME = "florencia-britos"
COURSE_NAME = "eccd-oct23"
EXERCISE_NAME = "cleaning-a-dataset"

# %%
import pandas as pd
import numpy as np
from eccd_datasets import load_lingerie
from pygradus import create_exercise, check_solution

# %%
datasets = load_lingerie()

# %%
datasets.keys()
# Out:
# dict_keys(['ae_com', 'amazon_com', 'btemptd_com', 'calvinklein_com', 'hankypanky_com', 'macys_com', 'shop_nordstrom_com', 'us_topshop_com', 'victoriassecret_com'])

# %% [markdown]
# ## The different datasets on their own

# %%
datasets["ae_com"].head()
# Out:
#                        product_name        mrp      price  \
# 0  Aerie Everyday Loves Lace Cheeky  12.50 USD  12.50 USD
# 1  Aerie Everyday Loves Lace Cheeky  12.50 USD  12.50 USD
# 2  Aerie Everyday Loves Lace Cheeky  12.50 USD  12.50 USD
# 3  Aerie Everyday Loves Lace Cheeky  12.50 USD  12.50 USD
# 4  Aerie Everyday Loves Lace Cheeky  12.50 USD  12.50 USD
#
#                                              pdp_url brand_name  \
# 0  https://www.ae.com/aerie-everyday-loves-lace-c...      AERIE
# 1  https://www.ae.com/aerie-everyday-loves-lace-c...      AERIE
# 2  https://www.ae.com/aerie-everyday-loves-lace-c...      AERIE
# 3  https://www.ae.com/aerie-everyday-loves-lace-c...      AERIE
# 4  https://www.ae.com/aerie-everyday-loves-lace-c...      AERIE
#
#   product_category retailer  \
# 0         Cheekies    Ae US
# 1         Cheekies    Ae US
# 2         Cheekies    Ae US
# 3         Cheekies    Ae US
# 4         Cheekies    Ae US
#
#                                          description  rating  review_count  \
# 0  Introducing Everyday Loves™: Made with love. E...     5.0           8.0
# 1  Introducing Everyday Loves™: Made with love. E...     5.0           8.0
# 2  Introducing Everyday Loves™: Made with love. E...     5.0           8.0
# 3  Introducing Everyday Loves™: Made with love. E...     5.0           8.0
# 4  Introducing Everyday Loves™: Made with love. E...     5.0           8.0
#
#                                     style_attributes  \
# 0  ["Soft lace with the right amount of stretch",...
# 1  ["Soft lace with the right amount of stretch",...
# 2  ["Soft lace with the right amount of stretch",...
# 3  ["Soft lace with the right amount of stretch",...
# 4  ["Soft lace with the right amount of stretch",...
#
#                           total_sizes                      available_size  \
# 0  ["XS", "S", "M", "L", "XL", "XXL"]  ["XS", "S", "M", "L", "XL", "XXL"]
# 1  ["XS", "S", "M", "L", "XL", "XXL"]  ["XS", "S", "M", "L", "XL", "XXL"]
# 2  ["XS", "S", "M", "L", "XL", "XXL"]  ["XS", "S", "M", "L", "XL", "XXL"]
# 3  ["XS", "S", "M", "L", "XL", "XXL"]  ["XS", "S", "M", "L", "XL", "XXL"]
# 4  ["XS", "S", "M", "L", "XL", "XXL"]  ["XS", "S", "M", "L", "XL", "XXL"]
#
#           color
# 0  Rugged Green
# 1  Natural Nude
# 2    True Black
# 3         White
# 4    Royal Navy

# %%
datasets["amazon_com"].head()
# Out:
#                                         product_name      mrp    price  \
# 0  Calvin Klein Women's Sheer Marquisette Demi Un...  $36.00   $32.40
# 1                   Wacoal Embrace Lace Bikini Panty  $27.00   $27.00
# 2     Wacoal Women's Slimline Seamless Minimizer Bra  $65.00   $65.00
# 3     Hanky Panky Womens Signature Lace Retro V-Kini  $36.00   $36.00
# 4            Wacoal Women's Red Carpet Strapless Bra  $65.00   $65.00
#
#                                              pdp_url    brand_name  \
# 0  https://www.amazon.com/-/dp/B01NAVD98J?th=1&psc=1  Calvin-Klein
# 1  https://www.amazon.com/-/dp/B0011YQFNK?th=1&psc=1        Wacoal
# 2  https://www.amazon.com/-/dp/B000T3606Q?th=1&psc=1        Wacoal
# 3  https://www.amazon.com/-/dp/B003Y6AX0Y?th=1&psc=1   Hanky-Panky
# 4  https://www.amazon.com/-/dp/B01CEBGQA0?th=1&psc=1        Wacoal
#
#   product_category   retailer  \
# 0             Bras  Amazon US
# 1          Panties  Amazon US
# 2             Bras  Amazon US
# 3          Panties  Amazon US
# 4             Bras  Amazon US
#
#                                          description  rating  review_count  \
# 0  An unlined demi cup bra featuring sheer, sexy ...     4.5            47
# 1  Embrace lace bikini offers great fit and match...     4.4            91
# 2  Seamless underwire minimizer bra gives great s...     4.3           298
# 3  All-day comfort describes this figure-flatteri...     4.4            46
# 4  Red Carpet full figure strapless fits great, s...     4.4           747
#
#                                     style_attributes  \
# 0  [ 72% Nylon, 28% Elastane , Imported , hook an...
# 1  [ 100% Nylon , Imported , Hand Wash , 1.2" hig...
# 2  [ Cups: 100% Polyester; Back: 71% Nylon, 29% S...
# 3  [ Made in USA , All-day comfort describes this...
# 4  [ 91% Nylon, 9% Spandex , Imported , hook and ...
#
#                                          total_sizes  \
# 0  30B , 30C , 30D , 30DD , 32A , 32B , 32C , 32D...
# 1                   Small , Medium , Large , X-Large
# 2  32DD , 32DDD , 34C , 34D , 34DD , 34DDD , 36C ...
# 3                   Small , Medium , Large , X-Large
# 4  30D , 30DD , 30DDD , 30G , 32C , 32D , 32DD , ...
#
#                                       available_size  color
# 0  30B , 30C , 30D , 30DD , 32B , 32C , 32D , 32D...   Bare
# 1                           Small , Medium , X-Large  Large
# 2  32DD , 32DDD , 34C , 34D , 34DD , 34DDD , 36C ...  Black
# 3                           Small , Medium , X-Large  Large
# 4  30D , 30DD , 30DDD , 30G , 32C , 32D , 32DD , ...  Pecan

# %% [markdown]
# ### Joining all the datasets into one

# %%
df = pd.concat(datasets.values())

# %%
df.shape
# Out:
# (613143, 14)

# %%
df
# Out:
#                             product_name        mrp      price  \
# 0       Aerie Everyday Loves Lace Cheeky  12.50 USD  12.50 USD
# 1       Aerie Everyday Loves Lace Cheeky  12.50 USD  12.50 USD
# 2       Aerie Everyday Loves Lace Cheeky  12.50 USD  12.50 USD
# 3       Aerie Everyday Loves Lace Cheeky  12.50 USD  12.50 USD
# 4       Aerie Everyday Loves Lace Cheeky  12.50 USD  12.50 USD
# ...                                  ...        ...        ...
# 453381  Dream Angels NEW! Lace Mini Slip    $48.00     $48.00
# 453382  Dream Angels NEW! Lace Mini Slip    $48.00     $48.00
# 453383  Dream Angels NEW! Lace Mini Slip    $48.00     $48.00
# 453384  Dream Angels NEW! Lace Mini Slip    $48.00     $48.00
# 453385  Dream Angels NEW! Lace Mini Slip    $48.00     $48.00
#
#                                                   pdp_url         brand_name  \
# 0       https://www.ae.com/aerie-everyday-loves-lace-c...              AERIE
# 1       https://www.ae.com/aerie-everyday-loves-lace-c...              AERIE
# 2       https://www.ae.com/aerie-everyday-loves-lace-c...              AERIE
# 3       https://www.ae.com/aerie-everyday-loves-lace-c...              AERIE
# 4       https://www.ae.com/aerie-everyday-loves-lace-c...              AERIE
# ...                                                   ...                ...
# 453381  https://www.victoriassecret.com/lingerie/shop-...  Victoria's Secret
# 453382  https://www.victoriassecret.com/lingerie/shop-...  Victoria's Secret
# 453383  https://www.victoriassecret.com/lingerie/shop-...  Victoria's Secret
# 453384  https://www.victoriassecret.com/lingerie/shop-...  Victoria's Secret
# 453385  https://www.victoriassecret.com/lingerie/shop-...  Victoria's Secret
#
#        product_category            retailer  \
# 0              Cheekies               Ae US
# 1              Cheekies               Ae US
# 2              Cheekies               Ae US
# 3              Cheekies               Ae US
# 4              Cheekies               Ae US
# ...                 ...                 ...
# 453381   Lace Mini Slip  Victoriassecret US
# 453382   Lace Mini Slip  Victoriassecret US
# 453383   Lace Mini Slip  Victoriassecret US
# 453384   Lace Mini Slip  Victoriassecret US
# 453385   Lace Mini Slip  Victoriassecret US
#
#                                               description  rating  \
# 0       Introducing Everyday Loves™: Made with love. E...     5.0
# 1       Introducing Everyday Loves™: Made with love. E...     5.0
# 2       Introducing Everyday Loves™: Made with love. E...     5.0
# 3       Introducing Everyday Loves™: Made with love. E...     5.0
# 4       Introducing Everyday Loves™: Made with love. E...     5.0
# ...                                                   ...     ...
# 453381  All you need is a little lace, here in the cut...     NaN
# 453382  All you need is a little lace, here in the cut...     NaN
# 453383  All you need is a little lace, here in the cut...     NaN
# 453384  All you need is a little lace, here in the cut...     NaN
# 453385  All you need is a little lace, here in the cut...     NaN
#
#         review_count                                   style_attributes  \
# 0                8.0  ["Soft lace with the right amount of stretch",...
# 1                8.0  ["Soft lace with the right amount of stretch",...
# 2                8.0  ["Soft lace with the right amount of stretch",...
# 3                8.0  ["Soft lace with the right amount of stretch",...
# 4                8.0  ["Soft lace with the right amount of stretch",...
# ...              ...                                                ...
# 453381           NaN                                                NaN
# 453382           NaN                                                NaN
# 453383           NaN                                                NaN
# 453384           NaN                                                NaN
# 453385           NaN                                                NaN
#
#                                total_sizes  \
# 0       ["XS", "S", "M", "L", "XL", "XXL"]
# 1       ["XS", "S", "M", "L", "XL", "XXL"]
# 2       ["XS", "S", "M", "L", "XL", "XXL"]
# 3       ["XS", "S", "M", "L", "XL", "XXL"]
# 4       ["XS", "S", "M", "L", "XL", "XXL"]
# ...                                    ...
# 453381         ["XS", "S", "M", "L", "XL"]
# 453382         ["XS", "S", "M", "L", "XL"]
# 453383         ["XS", "S", "M", "L", "XL"]
# 453384         ["XS", "S", "M", "L", "XL"]
# 453385         ["XS", "S", "M", "L", "XL"]
#
#                             available_size          color
# 0       ["XS", "S", "M", "L", "XL", "XXL"]   Rugged Green
# 1       ["XS", "S", "M", "L", "XL", "XXL"]   Natural Nude
# 2       ["XS", "S", "M", "L", "XL", "XXL"]     True Black
# 3       ["XS", "S", "M", "L", "XL", "XXL"]          White
# 4       ["XS", "S", "M", "L", "XL", "XXL"]     Royal Navy
# ...                                    ...            ...
# 453381                                   L  coconut white
# 453382                                   L   mulled grape
# 453383                                   M     sheer pink
# 453384                                   M  coconut white
# 453385                                   M   mulled grape
#
# [613143 rows x 14 columns]

# %% [markdown]
# # Calculating statistics on the dataset

# %% [markdown]
# ## Unifying Victoria's Secret

# %%
unique_brands = df['brand_name'].unique()
print(unique_brands)
# Out:
# ['AERIE' 'AEO' 'Calvin-Klein' 'Wacoal' 'Hanky-Panky' 'b-temptd'
#  'Victorias-Secret' 's'
#  'ref=w_bl_sl_l_ap_ap_web_2586685011?ie=UTF8&node=2586685011&field-lbr_brands_browse-bin=Calvin+Klein'
#  'ref=w_bl_sl_l_b_ap_web_2586451011?ie=UTF8&node=2586451011&field-lbr_brands_browse-bin=b.tempt%27d'
#  'Fila' 'Lucky-Brand'
#  'ref=w_bl_sl_l_b_ap_web_2603426011?ie=UTF8&node=2603426011&field-lbr_brands_browse-bin=Wacoal'
#  'Creative-Motion' 'Sexy-Hair' 'Nintendo' 'Compression-Comfort' 'WACOAL'
#  'Calvin Klein' 'HankyPanky' 'Hanky Panky' "b.tempt'd by Wacoal"
#  'Calvin Klein Modern Cotton' 'Vanity Fair' 'Calvin Klein Performance'
#  "b.tempt'd" 'HANKY PANKY' "B.TEMPT'D BY WACOAL" 'CALVIN KLEIN'
#  'NORDSTROM LINGERIE' 'US TOPSHOP' "Victoria's Secret"
#  "Victoria's Secret Pink"]

# %%
len(unique_brands)
# Out:
# 33

# %%
df[df['brand_name'] == 's']
# Out:
#                                             product_name      mrp    price  \
# 935                Wacoal Women's Front Close T-Back Bra  $46.00   $46.00
# 10417  b.tempt'd by Wacoal Women's Ciao Bella Balcone...  $38.00   $24.95
# 28997     Wacoal Women's Embrace Lace Hi-Cut Brief Panty  $27.00   $27.00
#
#                                                  pdp_url brand_name  \
# 935    https://www.amazon.com/-/dp/B0002NXT4Y?th=1&psc=1          s
# 10417  https://www.amazon.com/-/dp/B01FXTD1XK?th=1&psc=1          s
# 28997  https://www.amazon.com/-/dp/B006M0J8Q4?th=1&psc=1          s
#
#       product_category   retailer  \
# 935               Bras  Amazon US
# 10417             Bras  Amazon US
# 28997          Panties  Amazon US
#
#                                              description  rating  \
# 935    Pure comfort in a seamless molded front close ...     4.2
# 10417  Balconette features corded lace overlay with a...     4.3
# 28997  Embrace lace hi-cut brief offers great fit and...     4.5
#
#        review_count                                   style_attributes  \
# 935           742.0  [ Fabric: 87% Nylon , 13% Spandex; Top cup: 10...
# 10417         377.0  [ 86% Nylon/14% Spandex , Imported , Hand Wash...
# 28997          23.0  [ Body: 82% Nylon, 18% Spandex , Imported , Ha...
#
#                                              total_sizes  \
# 935    32C , 32D , 32DD , 34B , 34C , 34D , 34DD , 36...
# 10417  30C , 30D , 30DD , 30DDD , 32B , 32C , 32D , 3...
# 28997    Small , Medium , Large , X-Large , 2X , 2X Plus
#
#                                           available_size      color
# 935    32C , 32D , 32DD , 34B , 34C , 34D , 36B , 36C...      Black
# 10417  30C , 30D , 30DD , 30DDD , 32B , 32C , 32D , 3...  Baja Blue
# 28997                      Medium , Large , X-Large , 2X      Small

# %%
def unify_victoria_secret(df):
    """
    We want that all brands whose 'brand_name' contains 'victoria'
    to have `victoria's secret` as their brand instead of what they
    currently have.
    """
    df = df.copy()
    new_string = "victoria's secret"
    df.loc[df['brand_name'].str.contains('victoria', case=False, na=False), 'brand_name'] = new_string

    return df

# %%
df_unified = unify_victoria_secret(df)

# %%
df_unified
# Out:
#                             product_name        mrp      price  \
# 0       Aerie Everyday Loves Lace Cheeky  12.50 USD  12.50 USD
# 1       Aerie Everyday Loves Lace Cheeky  12.50 USD  12.50 USD
# 2       Aerie Everyday Loves Lace Cheeky  12.50 USD  12.50 USD
# 3       Aerie Everyday Loves Lace Cheeky  12.50 USD  12.50 USD
# 4       Aerie Everyday Loves Lace Cheeky  12.50 USD  12.50 USD
# ...                                  ...        ...        ...
# 453381  Dream Angels NEW! Lace Mini Slip    $48.00     $48.00
# 453382  Dream Angels NEW! Lace Mini Slip    $48.00     $48.00
# 453383  Dream Angels NEW! Lace Mini Slip    $48.00     $48.00
# 453384  Dream Angels NEW! Lace Mini Slip    $48.00     $48.00
# 453385  Dream Angels NEW! Lace Mini Slip    $48.00     $48.00
#
#                                                   pdp_url         brand_name  \
# 0       https://www.ae.com/aerie-everyday-loves-lace-c...              AERIE
# 1       https://www.ae.com/aerie-everyday-loves-lace-c...              AERIE
# 2       https://www.ae.com/aerie-everyday-loves-lace-c...              AERIE
# 3       https://www.ae.com/aerie-everyday-loves-lace-c...              AERIE
# 4       https://www.ae.com/aerie-everyday-loves-lace-c...              AERIE
# ...                                                   ...                ...
# 453381  https://www.victoriassecret.com/lingerie/shop-...  victoria's secret
# 453382  https://www.victoriassecret.com/lingerie/shop-...  victoria's secret
# 453383  https://www.victoriassecret.com/lingerie/shop-...  victoria's secret
# 453384  https://www.victoriassecret.com/lingerie/shop-...  victoria's secret
# 453385  https://www.victoriassecret.com/lingerie/shop-...  victoria's secret
#
#        product_category            retailer  \
# 0              Cheekies               Ae US
# 1              Cheekies               Ae US
# 2              Cheekies               Ae US
# 3              Cheekies               Ae US
# 4              Cheekies               Ae US
# ...                 ...                 ...
# 453381   Lace Mini Slip  Victoriassecret US
# 453382   Lace Mini Slip  Victoriassecret US
# 453383   Lace Mini Slip  Victoriassecret US
# 453384   Lace Mini Slip  Victoriassecret US
# 453385   Lace Mini Slip  Victoriassecret US
#
#                                               description  rating  \
# 0       Introducing Everyday Loves™: Made with love. E...     5.0
# 1       Introducing Everyday Loves™: Made with love. E...     5.0
# 2       Introducing Everyday Loves™: Made with love. E...     5.0
# 3       Introducing Everyday Loves™: Made with love. E...     5.0
# 4       Introducing Everyday Loves™: Made with love. E...     5.0
# ...                                                   ...     ...
# 453381  All you need is a little lace, here in the cut...     NaN
# 453382  All you need is a little lace, here in the cut...     NaN
# 453383  All you need is a little lace, here in the cut...     NaN
# 453384  All you need is a little lace, here in the cut...     NaN
# 453385  All you need is a little lace, here in the cut...     NaN
#
#         review_count                                   style_attributes  \
# 0                8.0  ["Soft lace with the right amount of stretch",...
# 1                8.0  ["Soft lace with the right amount of stretch",...
# 2                8.0  ["Soft lace with the right amount of stretch",...
# 3                8.0  ["Soft lace with the right amount of stretch",...
# 4                8.0  ["Soft lace with the right amount of stretch",...
# ...              ...                                                ...
# 453381           NaN                                                NaN
# 453382           NaN                                                NaN
# 453383           NaN                                                NaN
# 453384           NaN                                                NaN
# 453385           NaN                                                NaN
#
#                                total_sizes  \
# 0       ["XS", "S", "M", "L", "XL", "XXL"]
# 1       ["XS", "S", "M", "L", "XL", "XXL"]
# 2       ["XS", "S", "M", "L", "XL", "XXL"]
# 3       ["XS", "S", "M", "L", "XL", "XXL"]
# 4       ["XS", "S", "M", "L", "XL", "XXL"]
# ...                                    ...
# 453381         ["XS", "S", "M", "L", "XL"]
# 453382         ["XS", "S", "M", "L", "XL"]
# 453383         ["XS", "S", "M", "L", "XL"]
# 453384         ["XS", "S", "M", "L", "XL"]
# 453385         ["XS", "S", "M", "L", "XL"]
#
#                             available_size          color
# 0       ["XS", "S", "M", "L", "XL", "XXL"]   Rugged Green
# 1       ["XS", "S", "M", "L", "XL", "XXL"]   Natural Nude
# 2       ["XS", "S", "M", "L", "XL", "XXL"]     True Black
# 3       ["XS", "S", "M", "L", "XL", "XXL"]          White
# 4       ["XS", "S", "M", "L", "XL", "XXL"]     Royal Navy
# ...                                    ...            ...
# 453381                                   L  coconut white
# 453382                                   L   mulled grape
# 453383                                   M     sheer pink
# 453384                                   M  coconut white
# 453385                                   M   mulled grape
#
# [613143 rows x 14 columns]

# %%
unique_brands = df_unified['brand_name'].unique()
print(unique_brands)
# Out:
# ['AERIE' 'AEO' 'Calvin-Klein' 'Wacoal' 'Hanky-Panky' 'b-temptd'
#  "victoria's secret" 's'
#  'ref=w_bl_sl_l_ap_ap_web_2586685011?ie=UTF8&node=2586685011&field-lbr_brands_browse-bin=Calvin+Klein'
#  'ref=w_bl_sl_l_b_ap_web_2586451011?ie=UTF8&node=2586451011&field-lbr_brands_browse-bin=b.tempt%27d'
#  'Fila' 'Lucky-Brand'
#  'ref=w_bl_sl_l_b_ap_web_2603426011?ie=UTF8&node=2603426011&field-lbr_brands_browse-bin=Wacoal'
#  'Creative-Motion' 'Sexy-Hair' 'Nintendo' 'Compression-Comfort' 'WACOAL'
#  'Calvin Klein' 'HankyPanky' 'Hanky Panky' "b.tempt'd by Wacoal"
#  'Calvin Klein Modern Cotton' 'Vanity Fair' 'Calvin Klein Performance'
#  "b.tempt'd" 'HANKY PANKY' "B.TEMPT'D BY WACOAL" 'CALVIN KLEIN'
#  'NORDSTROM LINGERIE' 'US TOPSHOP']

# %%
len(unique_brands)
# Out:
# 31

# %%
answer_victoria_secret =df_unified[df_unified["brand_name"] == "victoria's secret"].shape[0]
print(answer_victoria_secret)
# Out:
# 453453

# %% [markdown]
# ## Cleaning up the price
#
# In this sectino we are going to transform the `price` column into a float column in USD dolars.
#
# For this, be careful of the different formats in the data.
#
# For simplicity, you might assume that all the prices are in USD dolars, regarding of the symbol of the currency used.

# %%
def clean_price(df):
    """
    In this function, we will transform the `price` column into a column of floats.
    In case a product has more than one price, return the lowest one.
    """
    df = df.copy()
    df['price'] = df['price'].str.replace('[^\d.]', '', regex=True).astype(float)

    return df

# %%
df_clean = clean_price(df_unified)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-137-38fdeb72255b> in <cell line: 1>()
# ----> 1 df_clean = clean_price(df_unified)
#
# <ipython-input-136-3e561cca0602> in clean_price(df)
#       5     """
#       6     df = df.copy()
# ----> 7     df['price'] = df['price'].str.replace('[^\d.]', '', regex=True).astype(float)
#       8
#       9     return df
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6238         else:
#    6239             # else, only a single dtype is given
# -> 6240             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241             return self._constructor(new_data).__finalize__(self, method="astype")
#    6242
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     446
#     447     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 448         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     449
#     450     def convert(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     350                     applied = b.apply(f, **kwargs)
#     351                 else:
# --> 352                     applied = getattr(b, f)(**kwargs)
#     353             except (TypeError, NotImplementedError):
#     354                 if not ignore_failures:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors)
#     524         values = self.values
#     525
# --> 526         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     527
#     528         new_values = maybe_coerce_values(new_values)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/dtypes/astype.py in astype_array_safe(values, dtype, copy, errors)
#     297
#     298     try:
# --> 299         new_values = astype_array(values, dtype, copy=copy)
#     300     except (ValueError, TypeError):
#     301         # e.g. astype_nansafe can fail on object-dtype of strings
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/dtypes/astype.py in astype_array(values, dtype, copy)
#     228
#     229     else:
# --> 230         values = astype_nansafe(values, dtype, copy=copy)
#     231
#     232     # in pandas we don't store numpy str dtypes, so convert to object
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/dtypes/astype.py in astype_nansafe(arr, dtype, copy, skipna)
#     168     if copy or is_object_dtype(arr.dtype) or is_object_dtype(dtype):
#     169         # Explicit copy, or required since NumPy can't view from / to object.
# --> 170         return arr.astype(dtype, copy=True)
#     171
#     172     return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: '19.9924.99'

# %%
pattern = r'19\.99.*24\.99|24\.99.*19\.99'
matching_rows = df[df['price'].str.contains(pattern)]

print(matching_rows)
print(len(matching_rows))
# Out:
#                 product_name      mrp            price  \
# 420   essentials push-up bra  $39.00   $19.99 - $24.99
# 421   essentials push-up bra  $39.00   $19.99 - $24.99
# 422   essentials push-up bra  $39.00   $19.99 - $24.99
# 423   essentials push-up bra  $39.00   $19.99 - $24.99
# 424   essentials push-up bra  $39.00   $19.99 - $24.99
# 425   essentials push-up bra  $39.00   $19.99 - $24.99
# 4244  essentials push-up bra  $39.00   $19.99 - $24.99
# 4245  essentials push-up bra  $39.00   $19.99 - $24.99
# 4246  essentials push-up bra  $39.00   $19.99 - $24.99
# 4247  essentials push-up bra  $39.00   $19.99 - $24.99
# 4248  essentials push-up bra  $39.00   $19.99 - $24.99
# 4249  essentials push-up bra  $39.00   $19.99 - $24.99
#
#                                                 pdp_url    brand_name  \
# 420   http://www.calvinklein.us/en/womens-clothing/w...  Calvin Klein
# 421   http://www.calvinklein.us/en/womens-clothing/w...  Calvin Klein
# 422   http://www.calvinklein.us/en/womens-clothing/w...  Calvin Klein
# 423   http://www.calvinklein.us/en/womens-clothing/w...  Calvin Klein
# 424   http://www.calvinklein.us/en/womens-clothing/w...  Calvin Klein
# 425   http://www.calvinklein.us/en/womens-clothing/w...  Calvin Klein
# 4244  http://www.calvinklein.us/en/womens-clothing/w...  Calvin Klein
# 4245  http://www.calvinklein.us/en/womens-clothing/w...  Calvin Klein
# 4246  http://www.calvinklein.us/en/womens-clothing/w...  Calvin Klein
# 4247  http://www.calvinklein.us/en/womens-clothing/w...  Calvin Klein
# 4248  http://www.calvinklein.us/en/womens-clothing/w...  Calvin Klein
# 4249  http://www.calvinklein.us/en/womens-clothing/w...  Calvin Klein
#
#      product_category         retailer  \
# 420              Bras  Calvin Klein US
# 421              Bras  Calvin Klein US
# 422              Bras  Calvin Klein US
# 423              Bras  Calvin Klein US
# 424              Bras  Calvin Klein US
# 425              Bras  Calvin Klein US
# 4244             Bras  Calvin Klein US
# 4245             Bras  Calvin Klein US
# 4246             Bras  Calvin Klein US
# 4247             Bras  Calvin Klein US
# 4248             Bras  Calvin Klein US
# 4249             Bras  Calvin Klein US
#
#                                             description  rating  review_count  \
# 420   part of wardrobe essentials, push-up padding a...     NaN           NaN
# 421   part of wardrobe essentials, push-up padding a...     NaN           NaN
# 422   part of wardrobe essentials, push-up padding a...     NaN           NaN
# 423   part of wardrobe essentials, push-up padding a...     NaN           NaN
# 424   part of wardrobe essentials, push-up padding a...     NaN           NaN
# 425   part of wardrobe essentials, push-up padding a...     NaN           NaN
# 4244  part of wardrobe essentials, push-up padding a...     NaN           NaN
# 4245  part of wardrobe essentials, push-up padding a...     NaN           NaN
# 4246  part of wardrobe essentials, push-up padding a...     NaN           NaN
# 4247  part of wardrobe essentials, push-up padding a...     NaN           NaN
# 4248  part of wardrobe essentials, push-up padding a...     NaN           NaN
# 4249  part of wardrobe essentials, push-up padding a...     NaN           NaN
#
#                                        style_attributes  \
# 420   ["push-up bra","moderate coverage","padded cup...
# 421   ["push-up bra","moderate coverage","padded cup...
# 422   ["push-up bra","moderate coverage","padded cup...
# 423   ["push-up bra","moderate coverage","padded cup...
# 424   ["push-up bra","moderate coverage","padded cup...
# 425   ["push-up bra","moderate coverage","padded cup...
# 4244  ["push-up bra","moderate coverage","padded cup...
# 4245  ["push-up bra","moderate coverage","padded cup...
# 4246  ["push-up bra","moderate coverage","padded cup...
# 4247  ["push-up bra","moderate coverage","padded cup...
# 4248  ["push-up bra","moderate coverage","padded cup...
# 4249  ["push-up bra","moderate coverage","padded cup...
#
#                                             total_sizes  \
# 420   32A,32B,32C,32D,32DD,34A,34B,34C,34D,34DD,36A,...
# 421   32A,32B,32C,32D,32DD,34A,34B,34C,34D,34DD,36A,...
# 422   32A,32B,32C,32D,32DD,34A,34B,34C,34D,34DD,36A,...
# 423   32A,32B,32C,32D,32DD,34A,34B,34C,34D,34DD,36A,...
# 424   32A,32B,32C,32D,32DD,34A,34B,34C,34D,34DD,36A,...
# 425   32A,32B,32C,32D,32DD,34A,34B,34C,34D,34DD,36A,...
# 4244  32A,32B,32C,32D,32DD,34A,34B,34C,34D,34DD,36A,...
# 4245  32A,32B,32C,32D,32DD,34A,34B,34C,34D,34DD,36A,...
# 4246  32A,32B,32C,32D,32DD,34A,34B,34C,34D,34DD,36A,...
# 4247  32A,32B,32C,32D,32DD,34A,34B,34C,34D,34DD,36A,...
# 4248  32A,32B,32C,32D,32DD,34A,34B,34C,34D,34DD,36A,...
# 4249  32A,32B,32C,32D,32DD,34A,34B,34C,34D,34DD,36A,...
#
#                                          available_size          color
# 420          32DD,34B,34C,34D,34DD,36A,36B,36C,36DD,38D          BLACK
# 421                             32D,34C,34D,36C,36D,38C     WATERSTONE
# 422             32D,34A,34B,34C,34D,36B,36C,36D,38B,38C        CK LOGO
# 423   32A,32B,32D,34A,34B,34C,34D,34DD,36A,36B,36C,3...          WHITE
# 424             32C,32D,34A,34B,34C,34D,36A,36B,36C,36D           BARE
# 425                                             32D,34D  DESERT SUNSET
# 4244      32DD,34A,34B,34C,34D,34DD,36A,36B,36C,36D,38D          BLACK
# 4245            32A,32C,32D,34C,34D,36B,36C,36D,38B,38C     WATERSTONE
# 4246  32A,32C,32D,34A,34B,34C,34D,36A,36B,36C,36D,38...        CK LOGO
# 4247  32A,32B,32C,32D,34A,34B,34C,34D,34DD,36A,36B,3...          WHITE
# 4248       32C,32D,34A,34B,34C,34D,36A,36B,36C,36D,36DD           BARE
# 4249                                        32D,34C,34D  DESERT SUNSET
# 12

# %%
# Encontrar filas que contengan un guion en 'price'
rows_with_hyphen = df[df['price'].str.contains('-', regex=False)]

print(rows_with_hyphen)
print(len(rows_with_hyphen))
# Out:
#                 product_name      mrp            price  \
# 420   essentials push-up bra  $39.00   $19.99 - $24.99
# 421   essentials push-up bra  $39.00   $19.99 - $24.99
# 422   essentials push-up bra  $39.00   $19.99 - $24.99
# 423   essentials push-up bra  $39.00   $19.99 - $24.99
# 424   essentials push-up bra  $39.00   $19.99 - $24.99
# 425   essentials push-up bra  $39.00   $19.99 - $24.99
# 4244  essentials push-up bra  $39.00   $19.99 - $24.99
# 4245  essentials push-up bra  $39.00   $19.99 - $24.99
# 4246  essentials push-up bra  $39.00   $19.99 - $24.99
# 4247  essentials push-up bra  $39.00   $19.99 - $24.99
# 4248  essentials push-up bra  $39.00   $19.99 - $24.99
# 4249  essentials push-up bra  $39.00   $19.99 - $24.99
#
#                                                 pdp_url    brand_name  \
# 420   http://www.calvinklein.us/en/womens-clothing/w...  Calvin Klein
# 421   http://www.calvinklein.us/en/womens-clothing/w...  Calvin Klein
# 422   http://www.calvinklein.us/en/womens-clothing/w...  Calvin Klein
# 423   http://www.calvinklein.us/en/womens-clothing/w...  Calvin Klein
# 424   http://www.calvinklein.us/en/womens-clothing/w...  Calvin Klein
# 425   http://www.calvinklein.us/en/womens-clothing/w...  Calvin Klein
# 4244  http://www.calvinklein.us/en/womens-clothing/w...  Calvin Klein
# 4245  http://www.calvinklein.us/en/womens-clothing/w...  Calvin Klein
# 4246  http://www.calvinklein.us/en/womens-clothing/w...  Calvin Klein
# 4247  http://www.calvinklein.us/en/womens-clothing/w...  Calvin Klein
# 4248  http://www.calvinklein.us/en/womens-clothing/w...  Calvin Klein
# 4249  http://www.calvinklein.us/en/womens-clothing/w...  Calvin Klein
#
#      product_category         retailer  \
# 420              Bras  Calvin Klein US
# 421              Bras  Calvin Klein US
# 422              Bras  Calvin Klein US
# 423              Bras  Calvin Klein US
# 424              Bras  Calvin Klein US
# 425              Bras  Calvin Klein US
# 4244             Bras  Calvin Klein US
# 4245             Bras  Calvin Klein US
# 4246             Bras  Calvin Klein US
# 4247             Bras  Calvin Klein US
# 4248             Bras  Calvin Klein US
# 4249             Bras  Calvin Klein US
#
#                                             description  rating  review_count  \
# 420   part of wardrobe essentials, push-up padding a...     NaN           NaN
# 421   part of wardrobe essentials, push-up padding a...     NaN           NaN
# 422   part of wardrobe essentials, push-up padding a...     NaN           NaN
# 423   part of wardrobe essentials, push-up padding a...     NaN           NaN
# 424   part of wardrobe essentials, push-up padding a...     NaN           NaN
# 425   part of wardrobe essentials, push-up padding a...     NaN           NaN
# 4244  part of wardrobe essentials, push-up padding a...     NaN           NaN
# 4245  part of wardrobe essentials, push-up padding a...     NaN           NaN
# 4246  part of wardrobe essentials, push-up padding a...     NaN           NaN
# 4247  part of wardrobe essentials, push-up padding a...     NaN           NaN
# 4248  part of wardrobe essentials, push-up padding a...     NaN           NaN
# 4249  part of wardrobe essentials, push-up padding a...     NaN           NaN
#
#                                        style_attributes  \
# 420   ["push-up bra","moderate coverage","padded cup...
# 421   ["push-up bra","moderate coverage","padded cup...
# 422   ["push-up bra","moderate coverage","padded cup...
# 423   ["push-up bra","moderate coverage","padded cup...
# 424   ["push-up bra","moderate coverage","padded cup...
# 425   ["push-up bra","moderate coverage","padded cup...
# 4244  ["push-up bra","moderate coverage","padded cup...
# 4245  ["push-up bra","moderate coverage","padded cup...
# 4246  ["push-up bra","moderate coverage","padded cup...
# 4247  ["push-up bra","moderate coverage","padded cup...
# 4248  ["push-up bra","moderate coverage","padded cup...
# 4249  ["push-up bra","moderate coverage","padded cup...
#
#                                             total_sizes  \
# 420   32A,32B,32C,32D,32DD,34A,34B,34C,34D,34DD,36A,...
# 421   32A,32B,32C,32D,32DD,34A,34B,34C,34D,34DD,36A,...
# 422   32A,32B,32C,32D,32DD,34A,34B,34C,34D,34DD,36A,...
# 423   32A,32B,32C,32D,32DD,34A,34B,34C,34D,34DD,36A,...
# 424   32A,32B,32C,32D,32DD,34A,34B,34C,34D,34DD,36A,...
# 425   32A,32B,32C,32D,32DD,34A,34B,34C,34D,34DD,36A,...
# 4244  32A,32B,32C,32D,32DD,34A,34B,34C,34D,34DD,36A,...
# 4245  32A,32B,32C,32D,32DD,34A,34B,34C,34D,34DD,36A,...
# 4246  32A,32B,32C,32D,32DD,34A,34B,34C,34D,34DD,36A,...
# 4247  32A,32B,32C,32D,32DD,34A,34B,34C,34D,34DD,36A,...
# 4248  32A,32B,32C,32D,32DD,34A,34B,34C,34D,34DD,36A,...
# 4249  32A,32B,32C,32D,32DD,34A,34B,34C,34D,34DD,36A,...
#
#                                          available_size          color
# 420          32DD,34B,34C,34D,34DD,36A,36B,36C,36DD,38D          BLACK
# 421                             32D,34C,34D,36C,36D,38C     WATERSTONE
# 422             32D,34A,34B,34C,34D,36B,36C,36D,38B,38C        CK LOGO
# 423   32A,32B,32D,34A,34B,34C,34D,34DD,36A,36B,36C,3...          WHITE
# 424             32C,32D,34A,34B,34C,34D,36A,36B,36C,36D           BARE
# 425                                             32D,34D  DESERT SUNSET
# 4244      32DD,34A,34B,34C,34D,34DD,36A,36B,36C,36D,38D          BLACK
# 4245            32A,32C,32D,34C,34D,36B,36C,36D,38B,38C     WATERSTONE
# 4246  32A,32C,32D,34A,34B,34C,34D,36A,36B,36C,36D,38...        CK LOGO
# 4247  32A,32B,32C,32D,34A,34B,34C,34D,34DD,36A,36B,3...          WHITE
# 4248       32C,32D,34A,34B,34C,34D,36A,36B,36C,36D,36DD           BARE
# 4249                                        32D,34C,34D  DESERT SUNSET
# 12

# %%
rows_with_dash_or_en_dash = df[df['price'].str.contains('[-–]', regex=True)]

print(rows_with_dash_or_en_dash)
print(len(rows_with_dash_or_en_dash))
# Out:
#                  product_name            mrp            price  \
# 420    essentials push-up bra        $39.00   $19.99 - $24.99
# 421    essentials push-up bra        $39.00   $19.99 - $24.99
# 422    essentials push-up bra        $39.00   $19.99 - $24.99
# 423    essentials push-up bra        $39.00   $19.99 - $24.99
# 424    essentials push-up bra        $39.00   $19.99 - $24.99
# ...                       ...            ...              ...
# 11424           'Retro' Thong  $23.00–$25.00    $23.00–$25.00
# 11425           'Retro' Thong  $23.00–$25.00    $23.00–$25.00
# 11426           'Retro' Thong  $23.00–$25.00    $23.00–$25.00
# 11699  Ali High Neck Bralette  $52.00–$56.00    $31.20–$33.60
# 11700  Ali High Neck Bralette  $52.00–$56.00    $31.20–$33.60
#
#                                                  pdp_url    brand_name  \
# 420    http://www.calvinklein.us/en/womens-clothing/w...  Calvin Klein
# 421    http://www.calvinklein.us/en/womens-clothing/w...  Calvin Klein
# 422    http://www.calvinklein.us/en/womens-clothing/w...  Calvin Klein
# 423    http://www.calvinklein.us/en/womens-clothing/w...  Calvin Klein
# 424    http://www.calvinklein.us/en/womens-clothing/w...  Calvin Klein
# ...                                                  ...           ...
# 11424  http://shop.nordstrom.com/s/hanky-panky-retro-...   HANKY PANKY
# 11425  http://shop.nordstrom.com/s/hanky-panky-retro-...   HANKY PANKY
# 11426  http://shop.nordstrom.com/s/hanky-panky-retro-...   HANKY PANKY
# 11699  http://shop.nordstrom.com/s/hanky-panky-ali-hi...   HANKY PANKY
# 11700  http://shop.nordstrom.com/s/hanky-panky-ali-hi...   HANKY PANKY
#
#          product_category         retailer  \
# 420                  Bras  Calvin Klein US
# 421                  Bras  Calvin Klein US
# 422                  Bras  Calvin Klein US
# 423                  Bras  Calvin Klein US
# 424                  Bras  Calvin Klein US
# ...                   ...              ...
# 11424  Skin-Tone Lingerie     Nordstrom US
# 11425  Skin-Tone Lingerie     Nordstrom US
# 11426  Skin-Tone Lingerie     Nordstrom US
# 11699                Bras     Nordstrom US
# 11700                Bras     Nordstrom US
#
#                                              description  rating  \
# 420    part of wardrobe essentials, push-up padding a...     NaN
# 421    part of wardrobe essentials, push-up padding a...     NaN
# 422    part of wardrobe essentials, push-up padding a...     NaN
# 423    part of wardrobe essentials, push-up padding a...     NaN
# 424    part of wardrobe essentials, push-up padding a...     NaN
# ...                                                  ...     ...
# 11424  An extra-wide waistband gives a supersoft stre...     4.8
# 11425  An extra-wide waistband gives a supersoft stre...     4.8
# 11426  An extra-wide waistband gives a supersoft stre...     4.8
# 11699  Made for layering with a high neck and cutaway...     NaN
# 11700  Made for layering with a high neck and cutaway...     NaN
#
#        review_count                                   style_attributes  \
# 420             NaN  ["push-up bra","moderate coverage","padded cup...
# 421             NaN  ["push-up bra","moderate coverage","padded cup...
# 422             NaN  ["push-up bra","moderate coverage","padded cup...
# 423             NaN  ["push-up bra","moderate coverage","padded cup...
# 424             NaN  ["push-up bra","moderate coverage","padded cup...
# ...             ...                                                ...
# 11424         109.0  ["Neon colors are brighter in person.", "100% ...
# 11425         109.0  ["Neon colors are brighter in person.", "100% ...
# 11426         109.0  ["Neon colors are brighter in person.", "100% ...
# 11699           NaN  ["Slips on over head", "100% nylon", "Hand was...
# 11700           NaN  ["Slips on over head", "100% nylon", "Hand was...
#
#                                              total_sizes  \
# 420    32A,32B,32C,32D,32DD,34A,34B,34C,34D,34DD,36A,...
# 421    32A,32B,32C,32D,32DD,34A,34B,34C,34D,34DD,36A,...
# 422    32A,32B,32C,32D,32DD,34A,34B,34C,34D,34DD,36A,...
# 423    32A,32B,32C,32D,32DD,34A,34B,34C,34D,34DD,36A,...
# 424    32A,32B,32C,32D,32DD,34A,34B,34C,34D,34DD,36A,...
# ...                                                  ...
# 11424                                              [nil]
# 11425                                              [nil]
# 11426                                              [nil]
# 11699                       ["Small", "Medium", "Large"]
# 11700                       ["Small", "Medium", "Large"]
#
#                                           available_size         color
# 420           32DD,34B,34C,34D,34DD,36A,36B,36C,36DD,38D         BLACK
# 421                              32D,34C,34D,36C,36D,38C    WATERSTONE
# 422              32D,34A,34B,34C,34D,36B,36C,36D,38B,38C       CK LOGO
# 423    32A,32B,32D,34A,34B,34C,34D,34DD,36A,36B,36C,3...         WHITE
# 424              32C,32D,34A,34B,34C,34D,36A,36B,36C,36D          BARE
# ...                                                  ...           ...
# 11424                                              [nil]          Nori
# 11425                                              [nil]  Coral Gables
# 11426                                              [nil]     Glow Pink
# 11699                       ["Small", "Medium", "Large"]  Tickled Pink
# 11700                       ["Small", "Medium", "Large"]   Blue/ White
#
# [187 rows x 14 columns]
# 187

# %%
import re

# Function to extract and return the minimum value from a price string
def extract_and_get_min(price_str):
    # Extract numeric values from the string using regular expressions
    numeric_values = [float(match) for match in re.findall(r'[\d.]+', price_str)]

    if numeric_values:
        return f"${min(numeric_values):.2f}"

    return price_str

# Apply the function to the 'price' column
df['price'] = df['price'].apply(extract_and_get_min)

print(df)
# Out:
#                             product_name        mrp   price  \
# 0       Aerie Everyday Loves Lace Cheeky  12.50 USD  $12.50
# 1       Aerie Everyday Loves Lace Cheeky  12.50 USD  $12.50
# 2       Aerie Everyday Loves Lace Cheeky  12.50 USD  $12.50
# 3       Aerie Everyday Loves Lace Cheeky  12.50 USD  $12.50
# 4       Aerie Everyday Loves Lace Cheeky  12.50 USD  $12.50
# ...                                  ...        ...     ...
# 453381  Dream Angels NEW! Lace Mini Slip    $48.00   $48.00
# 453382  Dream Angels NEW! Lace Mini Slip    $48.00   $48.00
# 453383  Dream Angels NEW! Lace Mini Slip    $48.00   $48.00
# 453384  Dream Angels NEW! Lace Mini Slip    $48.00   $48.00
# 453385  Dream Angels NEW! Lace Mini Slip    $48.00   $48.00
#
#                                                   pdp_url         brand_name  \
# 0       https://www.ae.com/aerie-everyday-loves-lace-c...              AERIE
# 1       https://www.ae.com/aerie-everyday-loves-lace-c...              AERIE
# 2       https://www.ae.com/aerie-everyday-loves-lace-c...              AERIE
# 3       https://www.ae.com/aerie-everyday-loves-lace-c...              AERIE
# 4       https://www.ae.com/aerie-everyday-loves-lace-c...              AERIE
# ...                                                   ...                ...
# 453381  https://www.victoriassecret.com/lingerie/shop-...  Victoria's Secret
# 453382  https://www.victoriassecret.com/lingerie/shop-...  Victoria's Secret
# 453383  https://www.victoriassecret.com/lingerie/shop-...  Victoria's Secret
# 453384  https://www.victoriassecret.com/lingerie/shop-...  Victoria's Secret
# 453385  https://www.victoriassecret.com/lingerie/shop-...  Victoria's Secret
#
#        product_category            retailer  \
# 0              Cheekies               Ae US
# 1              Cheekies               Ae US
# 2              Cheekies               Ae US
# 3              Cheekies               Ae US
# 4              Cheekies               Ae US
# ...                 ...                 ...
# 453381   Lace Mini Slip  Victoriassecret US
# 453382   Lace Mini Slip  Victoriassecret US
# 453383   Lace Mini Slip  Victoriassecret US
# 453384   Lace Mini Slip  Victoriassecret US
# 453385   Lace Mini Slip  Victoriassecret US
#
#                                               description  rating  \
# 0       Introducing Everyday Loves™: Made with love. E...     5.0
# 1       Introducing Everyday Loves™: Made with love. E...     5.0
# 2       Introducing Everyday Loves™: Made with love. E...     5.0
# 3       Introducing Everyday Loves™: Made with love. E...     5.0
# 4       Introducing Everyday Loves™: Made with love. E...     5.0
# ...                                                   ...     ...
# 453381  All you need is a little lace, here in the cut...     NaN
# 453382  All you need is a little lace, here in the cut...     NaN
# 453383  All you need is a little lace, here in the cut...     NaN
# 453384  All you need is a little lace, here in the cut...     NaN
# 453385  All you need is a little lace, here in the cut...     NaN
#
#         review_count                                   style_attributes  \
# 0                8.0  ["Soft lace with the right amount of stretch",...
# 1                8.0  ["Soft lace with the right amount of stretch",...
# 2                8.0  ["Soft lace with the right amount of stretch",...
# 3                8.0  ["Soft lace with the right amount of stretch",...
# 4                8.0  ["Soft lace with the right amount of stretch",...
# ...              ...                                                ...
# 453381           NaN                                                NaN
# 453382           NaN                                                NaN
# 453383           NaN                                                NaN
# 453384           NaN                                                NaN
# 453385           NaN                                                NaN
#
#                                total_sizes  \
# 0       ["XS", "S", "M", "L", "XL", "XXL"]
# 1       ["XS", "S", "M", "L", "XL", "XXL"]
# 2       ["XS", "S", "M", "L", "XL", "XXL"]
# 3       ["XS", "S", "M", "L", "XL", "XXL"]
# 4       ["XS", "S", "M", "L", "XL", "XXL"]
# ...                                    ...
# 453381         ["XS", "S", "M", "L", "XL"]
# 453382         ["XS", "S", "M", "L", "XL"]
# 453383         ["XS", "S", "M", "L", "XL"]
# 453384         ["XS", "S", "M", "L", "XL"]
# 453385         ["XS", "S", "M", "L", "XL"]
#
#                             available_size          color
# 0       ["XS", "S", "M", "L", "XL", "XXL"]   Rugged Green
# 1       ["XS", "S", "M", "L", "XL", "XXL"]   Natural Nude
# 2       ["XS", "S", "M", "L", "XL", "XXL"]     True Black
# 3       ["XS", "S", "M", "L", "XL", "XXL"]          White
# 4       ["XS", "S", "M", "L", "XL", "XXL"]     Royal Navy
# ...                                    ...            ...
# 453381                                   L  coconut white
# 453382                                   L   mulled grape
# 453383                                   M     sheer pink
# 453384                                   M  coconut white
# 453385                                   M   mulled grape
#
# [613143 rows x 14 columns]

# %%
rows_with_dash_or_en_dash = df[df['price'].str.contains('[-–]', regex=True)]

print(rows_with_dash_or_en_dash)
print(len(rows_with_dash_or_en_dash))
# Out:
# Empty DataFrame
# Columns: [product_name, mrp, price, pdp_url, brand_name, product_category, retailer, description, rating, review_count, style_attributes, total_sizes, available_size, color]
# Index: []
# 0

# %%
def clean_price(df):
    """
    In this function, we will transform the `price` column into a column of floats.
    In case a product has more than one price, return the lowest one.
    """
    df = df.copy()  # Make a copy to avoid modifying the original DataFrame

    # Function to extract and return the minimum price from a string
    def extract_and_get_min(price_str):
        # Extract numeric values from the string using regular expressions
        numeric_values = [float(match) for match in re.findall(r'[\d.]+', price_str)]

        if numeric_values:
            return min(numeric_values)

        return None  # Return None for non-numeric values

    # Apply the function to the 'price' column and replace it with the minimum prices
    df['price'] = df['price'].apply(extract_and_get_min)

    return df

# %%
clean_price(df)
# Out:
#                             product_name        mrp  price  \
# 0       Aerie Everyday Loves Lace Cheeky  12.50 USD   12.5
# 1       Aerie Everyday Loves Lace Cheeky  12.50 USD   12.5
# 2       Aerie Everyday Loves Lace Cheeky  12.50 USD   12.5
# 3       Aerie Everyday Loves Lace Cheeky  12.50 USD   12.5
# 4       Aerie Everyday Loves Lace Cheeky  12.50 USD   12.5
# ...                                  ...        ...    ...
# 453381  Dream Angels NEW! Lace Mini Slip    $48.00    48.0
# 453382  Dream Angels NEW! Lace Mini Slip    $48.00    48.0
# 453383  Dream Angels NEW! Lace Mini Slip    $48.00    48.0
# 453384  Dream Angels NEW! Lace Mini Slip    $48.00    48.0
# 453385  Dream Angels NEW! Lace Mini Slip    $48.00    48.0
#
#                                                   pdp_url         brand_name  \
# 0       https://www.ae.com/aerie-everyday-loves-lace-c...              AERIE
# 1       https://www.ae.com/aerie-everyday-loves-lace-c...              AERIE
# 2       https://www.ae.com/aerie-everyday-loves-lace-c...              AERIE
# 3       https://www.ae.com/aerie-everyday-loves-lace-c...              AERIE
# 4       https://www.ae.com/aerie-everyday-loves-lace-c...              AERIE
# ...                                                   ...                ...
# 453381  https://www.victoriassecret.com/lingerie/shop-...  Victoria's Secret
# 453382  https://www.victoriassecret.com/lingerie/shop-...  Victoria's Secret
# 453383  https://www.victoriassecret.com/lingerie/shop-...  Victoria's Secret
# 453384  https://www.victoriassecret.com/lingerie/shop-...  Victoria's Secret
# 453385  https://www.victoriassecret.com/lingerie/shop-...  Victoria's Secret
#
#        product_category            retailer  \
# 0              Cheekies               Ae US
# 1              Cheekies               Ae US
# 2              Cheekies               Ae US
# 3              Cheekies               Ae US
# 4              Cheekies               Ae US
# ...                 ...                 ...
# 453381   Lace Mini Slip  Victoriassecret US
# 453382   Lace Mini Slip  Victoriassecret US
# 453383   Lace Mini Slip  Victoriassecret US
# 453384   Lace Mini Slip  Victoriassecret US
# 453385   Lace Mini Slip  Victoriassecret US
#
#                                               description  rating  \
# 0       Introducing Everyday Loves™: Made with love. E...     5.0
# 1       Introducing Everyday Loves™: Made with love. E...     5.0
# 2       Introducing Everyday Loves™: Made with love. E...     5.0
# 3       Introducing Everyday Loves™: Made with love. E...     5.0
# 4       Introducing Everyday Loves™: Made with love. E...     5.0
# ...                                                   ...     ...
# 453381  All you need is a little lace, here in the cut...     NaN
# 453382  All you need is a little lace, here in the cut...     NaN
# 453383  All you need is a little lace, here in the cut...     NaN
# 453384  All you need is a little lace, here in the cut...     NaN
# 453385  All you need is a little lace, here in the cut...     NaN
#
#         review_count                                   style_attributes  \
# 0                8.0  ["Soft lace with the right amount of stretch",...
# 1                8.0  ["Soft lace with the right amount of stretch",...
# 2                8.0  ["Soft lace with the right amount of stretch",...
# 3                8.0  ["Soft lace with the right amount of stretch",...
# 4                8.0  ["Soft lace with the right amount of stretch",...
# ...              ...                                                ...
# 453381           NaN                                                NaN
# 453382           NaN                                                NaN
# 453383           NaN                                                NaN
# 453384           NaN                                                NaN
# 453385           NaN                                                NaN
#
#                                total_sizes  \
# 0       ["XS", "S", "M", "L", "XL", "XXL"]
# 1       ["XS", "S", "M", "L", "XL", "XXL"]
# 2       ["XS", "S", "M", "L", "XL", "XXL"]
# 3       ["XS", "S", "M", "L", "XL", "XXL"]
# 4       ["XS", "S", "M", "L", "XL", "XXL"]
# ...                                    ...
# 453381         ["XS", "S", "M", "L", "XL"]
# 453382         ["XS", "S", "M", "L", "XL"]
# 453383         ["XS", "S", "M", "L", "XL"]
# 453384         ["XS", "S", "M", "L", "XL"]
# 453385         ["XS", "S", "M", "L", "XL"]
#
#                             available_size          color
# 0       ["XS", "S", "M", "L", "XL", "XXL"]   Rugged Green
# 1       ["XS", "S", "M", "L", "XL", "XXL"]   Natural Nude
# 2       ["XS", "S", "M", "L", "XL", "XXL"]     True Black
# 3       ["XS", "S", "M", "L", "XL", "XXL"]          White
# 4       ["XS", "S", "M", "L", "XL", "XXL"]     Royal Navy
# ...                                    ...            ...
# 453381                                   L  coconut white
# 453382                                   L   mulled grape
# 453383                                   M     sheer pink
# 453384                                   M  coconut white
# 453385                                   M   mulled grape
#
# [613143 rows x 14 columns]

# %%
df_clean = clean_price(df_unified)

# %%
df_clean
# Out:
#                             product_name        mrp  price  \
# 0       Aerie Everyday Loves Lace Cheeky  12.50 USD   12.5
# 1       Aerie Everyday Loves Lace Cheeky  12.50 USD   12.5
# 2       Aerie Everyday Loves Lace Cheeky  12.50 USD   12.5
# 3       Aerie Everyday Loves Lace Cheeky  12.50 USD   12.5
# 4       Aerie Everyday Loves Lace Cheeky  12.50 USD   12.5
# ...                                  ...        ...    ...
# 453381  Dream Angels NEW! Lace Mini Slip    $48.00    48.0
# 453382  Dream Angels NEW! Lace Mini Slip    $48.00    48.0
# 453383  Dream Angels NEW! Lace Mini Slip    $48.00    48.0
# 453384  Dream Angels NEW! Lace Mini Slip    $48.00    48.0
# 453385  Dream Angels NEW! Lace Mini Slip    $48.00    48.0
#
#                                                   pdp_url         brand_name  \
# 0       https://www.ae.com/aerie-everyday-loves-lace-c...              AERIE
# 1       https://www.ae.com/aerie-everyday-loves-lace-c...              AERIE
# 2       https://www.ae.com/aerie-everyday-loves-lace-c...              AERIE
# 3       https://www.ae.com/aerie-everyday-loves-lace-c...              AERIE
# 4       https://www.ae.com/aerie-everyday-loves-lace-c...              AERIE
# ...                                                   ...                ...
# 453381  https://www.victoriassecret.com/lingerie/shop-...  victoria's secret
# 453382  https://www.victoriassecret.com/lingerie/shop-...  victoria's secret
# 453383  https://www.victoriassecret.com/lingerie/shop-...  victoria's secret
# 453384  https://www.victoriassecret.com/lingerie/shop-...  victoria's secret
# 453385  https://www.victoriassecret.com/lingerie/shop-...  victoria's secret
#
#        product_category            retailer  \
# 0              Cheekies               Ae US
# 1              Cheekies               Ae US
# 2              Cheekies               Ae US
# 3              Cheekies               Ae US
# 4              Cheekies               Ae US
# ...                 ...                 ...
# 453381   Lace Mini Slip  Victoriassecret US
# 453382   Lace Mini Slip  Victoriassecret US
# 453383   Lace Mini Slip  Victoriassecret US
# 453384   Lace Mini Slip  Victoriassecret US
# 453385   Lace Mini Slip  Victoriassecret US
#
#                                               description  rating  \
# 0       Introducing Everyday Loves™: Made with love. E...     5.0
# 1       Introducing Everyday Loves™: Made with love. E...     5.0
# 2       Introducing Everyday Loves™: Made with love. E...     5.0
# 3       Introducing Everyday Loves™: Made with love. E...     5.0
# 4       Introducing Everyday Loves™: Made with love. E...     5.0
# ...                                                   ...     ...
# 453381  All you need is a little lace, here in the cut...     NaN
# 453382  All you need is a little lace, here in the cut...     NaN
# 453383  All you need is a little lace, here in the cut...     NaN
# 453384  All you need is a little lace, here in the cut...     NaN
# 453385  All you need is a little lace, here in the cut...     NaN
#
#         review_count                                   style_attributes  \
# 0                8.0  ["Soft lace with the right amount of stretch",...
# 1                8.0  ["Soft lace with the right amount of stretch",...
# 2                8.0  ["Soft lace with the right amount of stretch",...
# 3                8.0  ["Soft lace with the right amount of stretch",...
# 4                8.0  ["Soft lace with the right amount of stretch",...
# ...              ...                                                ...
# 453381           NaN                                                NaN
# 453382           NaN                                                NaN
# 453383           NaN                                                NaN
# 453384           NaN                                                NaN
# 453385           NaN                                                NaN
#
#                                total_sizes  \
# 0       ["XS", "S", "M", "L", "XL", "XXL"]
# 1       ["XS", "S", "M", "L", "XL", "XXL"]
# 2       ["XS", "S", "M", "L", "XL", "XXL"]
# 3       ["XS", "S", "M", "L", "XL", "XXL"]
# 4       ["XS", "S", "M", "L", "XL", "XXL"]
# ...                                    ...
# 453381         ["XS", "S", "M", "L", "XL"]
# 453382         ["XS", "S", "M", "L", "XL"]
# 453383         ["XS", "S", "M", "L", "XL"]
# 453384         ["XS", "S", "M", "L", "XL"]
# 453385         ["XS", "S", "M", "L", "XL"]
#
#                             available_size          color
# 0       ["XS", "S", "M", "L", "XL", "XXL"]   Rugged Green
# 1       ["XS", "S", "M", "L", "XL", "XXL"]   Natural Nude
# 2       ["XS", "S", "M", "L", "XL", "XXL"]     True Black
# 3       ["XS", "S", "M", "L", "XL", "XXL"]          White
# 4       ["XS", "S", "M", "L", "XL", "XXL"]     Royal Navy
# ...                                    ...            ...
# 453381                                   L  coconut white
# 453382                                   L   mulled grape
# 453383                                   M     sheer pink
# 453384                                   M  coconut white
# 453385                                   M   mulled grape
#
# [613143 rows x 14 columns]

# %%
df_clean['price'].isna().sum()
# Out:
# 0

# %%
answer_unified_price_sum = df_clean["price"].sum()
print(answer_unified_price_sum)
# Out:
# 20191976.02

# %%
def low_high_product_mean(df):
    """
    Finally, we will calculate `product_category` with the lowest and highest mean price
    for the brand Victoria's Secret.
    """
    df = df.copy()
    victorias_secret_df = df[df['brand_name'] == "victoria's secret"]
    mean_prices_by_category = victorias_secret_df.groupby('product_category')['price'].mean()
    lowest_mean = mean_prices_by_category.min()
    highest_mean = mean_prices_by_category.max()

    return lowest_mean, highest_mean

# %%
lowest_mean, highest_mean = low_high_product_mean(df_clean)

# %%
lowest_mean
# Out:
# 3.6203030303030306

# %%
highest_mean
# Out:
# 98.0

# %%
lowest_mean, highest_mean = low_high_product_mean(df_clean)
assert np.allclose(lowest_mean, 3.6203030303030)
print("highest_mean", highest_mean)
# Out:
# highest_mean 98.0

# %%
proposed_solution = {
'attempt': {
    'course_name': COURSE_NAME,
    'exercise_name': EXERCISE_NAME,
    'username': STUDENT_NAME,
},
'task_attempts': [
         {
            "name": "victoria secret",
            "answer": str(answer_victoria_secret),
         },
         {
            "name": "price unification",
            "answer": str(answer_unified_price_sum),
         },
         {
            "name": "highest mean",
            "answer": str(highest_mean),
         },
]

}
check_solution(proposed_solution)
# Out:
# |                    Task Name                     |       Status       |
# |--------------------------------------------------|--------------------|
# |--------------------------------------------------|--------------------|
# |                 victoria secret                  |      Correct       |
# |--------------------------------------------------|--------------------|
# |                price unification                 |      Correct       |
# |--------------------------------------------------|--------------------|
# |                   highest mean                   |      Correct       |
# |--------------------------------------------------|--------------------|
